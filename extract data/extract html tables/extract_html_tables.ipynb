# %% [markdown]
# **Extract table from website**

# %%
# import library
import pandas as pd

# %%
# Extract tables from website
x = pd.read_html("https://en.wikipedia.org/wiki/Body_mass_index")

# %%
# Return number of tables
len(x)
# Out:
# 9

# %%
# Extract index 4 table
x[4]
# Out:
#              Category BMI (kg/m2)[c]
# 0  Underweight (Thin)         < 18.5
# 1       Normal weight      18.5–24.9
# 2   Obesity (Class 1)      25.0–29.9
# 3   Obesity (Class 2)      30.0–34.9
# 4   Obesity (Class 3)      35.0–39.9
# 5   Obesity (Class 4)         ≥ 40.0
